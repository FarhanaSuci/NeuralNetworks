# %%
#a simple neural network with one output neuron, four inputs and weights, and biase
inputs = [1.0, 2.0, 3.0,2.5]
weights = [0.2, 0.8, -0.5, 1.0]
bias = 2.0
output = (inputs[0]*weights[0]+inputs[1]*weights[1]+inputs[2]*weights[2]+inputs[3]*weights[3]+bias)
print(output)
# Out:
# 4.8

# %% [markdown]
# # Exercise: Design the previous examples of neural network by adjusting weights and biases randomly.

# %%
import random
inputs=[1,2,3,2.5]
weights=[]
for i in range(len(inputs)):
    weights.append(random.random())
#print(weights)
bias=random.randint(2,4)
#print(bias)
output_neuron=(inputs[0]*weights[0]+inputs[1]*weights[1]+inputs[2]*weights[2]+inputs[3]*weights[3]+bias)
print(output_neuron)
# Out:
# 6.327028725709549

# %% [markdown]
# # Example-2: A fully connected neural network — every neuron in the current layer has connections to every neuron from the previous layer

# %%
#Let’s say we have a scenario with 3 neurons in a layer and 4 inputs:
#
inputs = [1, 2, 3, 2.5]
weights1 = [0.2, 0.8, -0.5, 1]
weights2 = [0.5, -0.91, 0.26, -0.5]
weights3 = [-0.26, -0.27, 0.17, 0.87]
bias1 = 2
bias2 = 3
bias3 =0.5

outputs = [
    # Neuron 1:
    inputs[0]*weights1[0]+
    inputs[1]*weights1[1]+inputs[2]*weights1[2]+
    inputs[3]*weights1[3]+bias1,

    # Neuron 2:
    inputs[0]*weights2[0]+
    inputs[1]*weights2[1]+
    inputs[2]*weights2[2]+
    inputs[3]*weights2[3]+bias2,

    # Neuron 3:
    inputs[0]*weights3[0]+
    inputs[1]*weights3[1]+
    inputs[2]*weights3[2]+
    inputs[3]*weights3[3]+bias3]

print(outputs)
# Out:
# [4.8, 1.21, 2.385]

# %% [markdown]
# # **Exercise**: A fully connected neural network — every neuron in the current layer has connections to every neuron from the previous layer. You have 4 input neurons, one hidden layer consisting of 3 neurons and one output neuron. You should adust weights and biases randomly.

# %%
import random
inputs=[1,2,3,2.5]
weights=[]
rows,cols=3,4
for i in range(rows):
    col=[]
    for k in range(cols):
      col.append(random.random())
    weights.append(col)
hidden_layer=3
bias=[]
for j in range(hidden_layer):
    bias.append(random.randint(-5,5))
print("First layer input weight is: ")
print(weights)
print("Hidden layer neuron bias is: ")
print(bias)
layer_outputs=[]
for neuron_weights,neuron_bias in zip(weights,bias):
    neuron_output=0
    for each_input,each_weight in zip(inputs,neuron_weights):
        neuron_output+=each_input*each_weight
    neuron_output+=neuron_bias
    layer_outputs.append(neuron_output)
print("Hidden layer is: ")
print(layer_outputs)
weights2=[]
for i in range(3):
    weights2.append(random.random())
print("Hidden layer neuron weight is: ")
print(weights2)
bias2=random.randint(-5,5)
output_neuron=(layer_outputs[0]*weights2[0]+layer_outputs[1]*weights2[1]+layer_outputs[2]*weights2[2]+bias2)
print("Output neuron is: ")
print(output_neuron)
# Out:
# First layer input weight is:
# [[0.8872460010329231, 0.16976373893432062, 0.43966966655921413, 0.84485904017962], [0.11315826270177587, 0.733698051304559, 0.6697032119787442, 0.045375659931669254], [0.5255328542693668, 0.7517139150905662, 0.8323661364989045, 0.030885457108002057]]
# Hidden layer neuron bias is:
# [0, 3, 0]
# Hidden layer is:
# [4.657930079028256, 6.7031031510762995, 4.6032727367172175]
# Hidden layer neuron weight is:
# [0.13364594708044364, 0.183510791857049, 0.2939084913361466]
# Output neuron is:
# -1.7944538107429189

# %% [markdown]
# # Example-3: Using loop option to get the weights, inputs and biases then feed into the neurons.

# %%
# this is more complex then previous one. It is variation of the previous code.
# I use a loop to get the weights, inputs and biases then feed into the neurons.
inputs = [1, 2, 3, 2.5]
weights = [
    [0.2, 0.8, -0.5, 1],
    [0.5, -0.91, 0.26, -0.5],
    [-0.26, -0.27, 0.17, 0.87]
]
biases = [2, 3, 0.5]

# Output of the current layer
layer_outputs = []


# For each neuron
for neuron_weights, neuron_bias in zip(weights, biases):
    # Zeroed output of the given neuron
    neuron_output = 0

    # For each input and weight to the neuron
    for n_input, weight in zip(inputs, neuron_weights):
        # Multiply this input by the associated weight
        # and add to the neuron's output variable

        neuron_output += n_input * weight

    # Add bias
    neuron_output += neuron_bias

    # Put the neuron's result into the layer's output list
    layer_outputs.append(neuron_output)

#print(layer_outputs)
w_out=[0.2, 0.8, -0.5]
biase_out=0.5
final_output=(layer_outputs[0]*w_out[0]+layer_outputs[1]*w_out[1]+layer_outputs[2]*w_out[2])+biase_out
print(final_output)
# Out:
# 1.2355

# %% [markdown]
# # Example-4: Using numpy library to calculate dot product in the neural network.

# %%
# previous probrams with numpy library, to make it faster and easily programmable.
import numpy as np

inputs = [1.0, 2.0, 3.0, 2.5]
weights = [0.2, 0.8, -0.5, 1.0]
bias = 2.0

outputs = np.dot(weights, inputs) + bias
print(outputs)
# Out:
# 4.8

# %%
# numpy library to make the complex code into simple one.
inputs = [1, 2, 3, 2.5]
weights = [
    [0.2, 0.8, -0.5, 1],
    [0.5, -0.91, 0.26, -0.5],
    [-0.26, -0.27, 0.17, 0.87]
]
biases = [2, 3, 0.5]

outputs = np.dot(weights, inputs) + biases
print(outputs)
# Out:
# [4.8   1.21  2.385]

# %% [markdown]
# # Exercise: take inputs containing 3 samples with 4 features, and 3 neurons with weights and biases, respectively. Then print the outputs of the neorons.

# %%
import numpy
inputs=[[1.0, 2.0, 3.0, 2.5],
      [2.0, 4.0, 1.5, 2.0],
         [0.5, 1.5, 2.0, 3.5]]
weights=[[0.2, 0.8, -0.5, 1.0],
                    [0.5, -0.9, 0.3, -0.7],
                    [-0.1, 0.6, -0.3, 0.9]]
bias=[2.0,1.0,-0.5]
outputs=[]

for input_sample in inputs:
   sample_outputs=[]
   for neuron_bias,neuron_weights in zip(bias,weights):
       neuron_output=0
       for weight,each_input in zip(neuron_weights,input_sample):
         neuron_output+=weight*each_input
       neuron_output+=neuron_bias
       sample_outputs.append(neuron_output)
   #print("sample output  is:")
   #print(sample_outputs)
   outputs.append(sample_outputs)
print("           ")
print("Final output is: ",end="\n")
print(numpy.array(outputs))
# Out:
#
# Final output is:
# [[ 4.8  -1.15  1.95]
#  [ 6.85 -2.55  3.05]
#  [ 5.8  -1.95  2.9 ]]

# %% [markdown]
# # Example-5: inputs-batch with weights and then transpose them to calculate dot product.

# %% [markdown]
# inputs = [[1.0, 2.0, 3.0, 2.5],
#           [2.0, 4.0, 1.5, 2.0],
#           [0.5, 1.5, 2.0, 3.5]]
#
# weights = [[0.2, 0.8, -0.5, 1.0],
#            [0.5, -0.9, 0.3, -0.7],
#            [-0.1, 0.6, -0.3, 0.9]]

# %%
# inputs-batch with weights and then transpose them to calculate dot product.
import numpy as np


inputs = np.array([[1.0, 2.0, 3.0, 2.5],
                   [2.0, 4.0, 1.5, 2.0],
                   [0.5, 1.5, 2.0, 3.5],
                   [0.5, 1.5, 2.0, 3.5],
                   [0.5, 1.5, 2.0, 3.5]])

weights = np.array([[0.2, 0.8, -0.5, 1.0],
                    [0.5, -0.9, 0.3, -0.7],
                    [-0.1, 0.6, -0.3, 0.9]])

biases = np.array([2.0, 1.0, -0.5])

outputs = np.dot(inputs, weights.T)+biases
print(outputs)
# Out:
# [[ 4.8  -1.15  1.95]
#  [ 6.85 -2.55  3.05]
#  [ 5.8  -1.95  2.9 ]
#  [ 5.8  -1.95  2.9 ]
#  [ 5.8  -1.95  2.9 ]]

# %% [markdown]
# # Example-6: Two hidden layers with four neurons at the first layer and three in the second.

# %%
# two hidden layers with three neurons at the first layer and three in the second.
import numpy as np
inputs = [[1, 2, 3, 2.5],
          [2., 5., -1., 2],
          [-1.5, 2.7, 3.3, -0.8]
          ]

weights = [[0.2, 0.8, -0.5, 1],
           [0.5, -0.91, 0.26, -0.5],
           [-0.26, -0.27, 0.17, 0.87]]
biases = [2, 3, 0.5]
weights2 = [[0.1, -0.14, 0.5],
            [-0.5, 0.12, -0.33],
            [-0.44, 0.73, -0.13]]
biases2 = [-1, 2, -0.5]
layer1_outputs = np.dot(inputs, np.array(weights).T) + biases

layer2_outputs = np.dot(layer1_outputs, np.array(weights2).T) + biases2
print(layer2_outputs)
# Out:
# [[ 0.5031  -1.04185 -2.03875]
#  [ 0.2434  -2.7332  -5.7633 ]
#  [-0.99314  1.41254 -0.35655]]

# %% [markdown]
# # Example-7: Activation functions.

# %%
# Sigmlidal activatino function
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Example usage
x = np.array([0.5, -1.0, 2.0])
output = sigmoid(x)
print(output)
# Out:
# [0.62245933 0.26894142 0.88079708]

# %%
# The Rectified Linear Unit (ReLU) activation function
import numpy as np

def relu(x):
    return np.maximum(0, x)

# Example usage
x = np.array([-2.0, -1.0, 0.0, 1.0, 2.0])
output = relu(x)
print(output)
# Out:
# [0. 0. 0. 1. 2.]

# %% [markdown]
# For solving logic gates, the activation function that is commonly used is the step function or the binary step function. The step function is a threshold-based function that outputs 0 if the input is less than or equal to a certain threshold and outputs 1 if the input is greater than the threshold.

# %%
# we will use it to solve logic gates problems.
def step_function(x, threshold=0):
    if x <= threshold:
        return 0
    else:
        return 1

# Example usage
x = 0.5
output = step_function(x)
print(output)
# Out:
# 1

# %% [markdown]
# #Example-8: Solve AND gate problem using neural network.

# %%
import numpy as np

# Define the inputs and corresponding labels for the AND gate
inputs = np.array([[0, 0],
                   [0, 1],
                   [1, 0],
                   [1, 1]])

labels = np.array([0, 0, 0, 1])

# Define the weights and biases for the neural network
weights = np.array([0.5, 0.5])
bias = -0.7

# Define the activation function (step function)
def step_function(x):
    return 0 if x <= 0 else 1

# Perform the forward pass to compute the outputs
outputs = []
for input_row in inputs:
    weighted_sum = np.dot(input_row, weights) + bias
    output = step_function(weighted_sum)
    outputs.append(output)

# Compare the predicted outputs with the actual labels
correct_predictions = np.sum(outputs == labels)

# Print the results
print("Inputs:", inputs)
print("Labels:", labels)
print("Predicted Outputs:", outputs)
print("Correct Predictions:", correct_predictions)
# Out:
# Inputs: [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
# Labels: [0 0 0 1]
# Predicted Outputs: [0, 0, 0, 1]
# Correct Predictions: 4

# %%
import numpy as np

# Define the inputs and corresponding labels for the AND gate
inputs = np.array([[0, 0],
                   [0, 1],
                   [1, 0],
                   [1, 1]])

labels = np.array([0, 0, 0, 1])

# Define the weights and bias for the neural network
weights = np.array([-0.5, 0.5])  # Modified weights
bias = 0.8  # Modified bias

# Define the activation function (step function)
def step_function(x):
    return 0 if x <= 0 else 1

# Perform the forward pass to compute the outputs
outputs = []
for input_row in inputs:
    weighted_sum = np.dot(input_row, weights) + bias
    output = step_function(weighted_sum)
    outputs.append(output)

# Compare the predicted outputs with the actual labels
correct_predictions = np.sum(outputs == labels)

# Print the results
print("Inputs:", inputs)
print("Labels:", labels)
print("Predicted Outputs:", outputs)
print("Correct Predictions:", correct_predictions)
# Out:
# Inputs: [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
# Labels: [0 0 0 1]
# Predicted Outputs: [1, 1, 1, 1]
# Correct Predictions: 1

# %% [markdown]
# # **Exercise**: Design the previous examples of neural network by adjusting weights and biases **randomly**.

# %%
#For 2 inputs and 1 output
import numpy
inputs=numpy.array([[0,0],[0,1],[1,0],[1,1]])
input_size=2
output_size=1
weight_size=2
labels=numpy.array([0,0,0,1])
weights=numpy.random.randn(input_size)
bias=numpy.random.randn(output_size)
def step_function(x):
    return 0 if x<=0 else 1
outputs=[]
for input_row in inputs:
    weighted_sum=numpy.dot(input_row,weights)+bias
    output=step_function(weighted_sum)
    outputs.append(output)
correct_predictions=numpy.sum(outputs==labels)
print("Inputs ",inputs)
print("Labels ",labels)
print("Random Biases ",bias)
print("Random weights ",weights)
print("Predicted outputs ",outputs)
print("Correct predictions ",correct_predictions)
# Out:
# Inputs  [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
# Labels  [0 0 0 1]
# Random Biases  [-0.71984421]
# Random weights  [-0.3011037  -1.47852199]
# Predicted outputs  [0, 0, 0, 0]
# Correct predictions  3

# %% [markdown]
# #**Exercise**: Design a neural network that has four input neurons, two hidden layers, and one output layer neuron. The activation function in the output payer should be sigmoidal. You should also adjust the weights and biases randomly. Moreover, the input dataset should contain 10 samples. Follow the figure:
#
# ![ann.PNG](data:image/png;base64,...)

# %%
import numpy
def sigmoid_function(x):
    return 1 / (1 + numpy.exp(-x))

inputs=numpy.random.randn(10,4)
print("\nInput Layer : \n\n",inputs)
input_size=4
hidden_layer1_size=3
hidden_layer2_size=3
output_size=1
weights1=numpy.random.randn(hidden_layer1_size,input_size)
weights2=numpy.random.randn(hidden_layer2_size,hidden_layer1_size)
weights3=numpy.random.randn(output_size,hidden_layer2_size)
print("\nWeights1 :  \n\n",weights1)
print("\nWeights2 : \n\n",weights2)
print("\nWeights3 : \n\n",weights3)
bias1=numpy.random.randn(hidden_layer1_size)
bias2=numpy.random.randn(hidden_layer2_size)
bias3=numpy.random.randn(output_size)
print("\nBias1: \n\n ",bias1)
print("\nBias2: \n\n ",bias2)
print("\nBias3: \n\n ",bias3)
output1=[]
for input_row in inputs:
    weighted_sum = numpy.dot(input_row,numpy.array(weights1).T)+ bias1
    output = sigmoid_function(weighted_sum)
    output1.append(output)
bias2=numpy.array(bias2)
weights2=numpy.array(weights2)
output2=[]
for input_row in output1:
    weighted_sum = numpy.dot(input_row,numpy.array(weights2))+ bias2
    output = sigmoid_function(weighted_sum)
    output2.append(output)
print("\nHidden layer:1 \n\n",numpy.array(output1))
print("\nHidden layer:2 \n\n",numpy.array(output2))
output3=[]
for input_row in output2:
    weighted_sum = numpy.dot(input_row,numpy.array(weights3).T)+ bias3
    output = sigmoid_function(weighted_sum)
    output3.append(output)
print("\nOutput layer: \n\n",numpy.array(output3))
# Out:
# Input Layer :
#
#  [[-0.46063877  1.05712223  0.34361829 -1.76304016]
#  [ 0.32408397 -0.38508228 -0.676922    0.61167629]
#  [ 1.03099952  0.93128012 -0.83921752 -0.30921238]
#  [ 0.33126343  0.97554513 -0.47917424 -0.18565898]
#  [-1.10633497 -1.19620662  0.81252582  1.35624003]
#  [-0.07201012  1.0035329   0.36163603 -0.64511975]
#  [ 0.36139561  1.53803657 -0.03582604  1.56464366]
#  [-2.6197451   0.8219025   0.08704707 -0.29900735]
#  [ 0.09176078 -1.98756891 -0.21967189  0.35711257]
#  [ 1.47789404 -0.51827022 -0.8084936  -0.50175704]]
#
# Weights1 :
#
#  [[ 0.91540212  0.32875111 -0.5297602   0.51326743]
#  [ 0.09707755  0.96864499 -0.70205309 -0.32766215]
#  [-0.39210815 -1.46351495  0.29612028  0.26105527]]
#
# Weights2 :
#
#  [[ 0.00511346 -0.23458713 -1.41537074]
#  [-0.42064532 -0.34271452 -0.80227727]
#  [-0.16128571  0.40405086  1.8861859 ]]
#
# Weights3 :
#
#  [[ 0.17457781  0.25755039 -0.07444592]]
#
# Bias1:
#
#   [-1.91877122 -0.02651388  0.06023021]
#
# Bias2:
#
#   [ 2.46324211 -0.19236096  0.30154734]
#
# Bias3:
#
#   [-0.03471177]
#
# Hidden layer:1
#
#  [[0.04394581 0.78400969 0.15912375]
#  [0.2542371  0.47670473 0.61205508]
#  [0.40541383 0.84106121 0.11545359]
#  [0.24300664 0.79377634 0.15607246]
#  [0.04482636 0.09050878 0.94476599]
#  [0.10179145 0.7101384  0.19130643]
#  [0.43530033 0.73318807 0.12624608]
#  [0.01411537 0.63463685 0.45817446]
#  [0.10078605 0.12947084 0.95079315]
#  [0.36227268 0.58587748 0.46725554]]
#
# Hidden layer:2
#
#  [[0.89167951 0.39961549 0.47763781]
#  [0.89709013 0.45808014 0.67121995]
#  [0.89021174 0.37073602 0.32535694]
#  [0.89142829 0.38737859 0.40495907]
#  [0.90661795 0.53689238 0.87517298]
#  [0.89418224 0.40556815 0.48714941]
#  [0.89441884 0.3787773  0.33969346]
#  [0.89306711 0.44323436 0.65398818]
#  [0.90516226 0.53090883 0.863939  ]
#  [0.89503974 0.42816565 0.54985672]]
#
# Output layer:
#
#  [[0.54694101]
#  [0.54733517]
#  [0.54784346]
#  [0.54748987]
#  [0.54901394]
#  [0.5472537 ]
#  [0.548274  ]
#  [0.54653156]
#  [0.54877651]
#  [0.54757612]]

# %% [markdown]
# #**Exercise**: Create a dataset using pandas for the following attbituts and then predict the housing prices using neural network:
# * Area: The total area of the house in square feet
# * Bedrooms: The number of bedrooms in the house.
# * Bathrooms: The number of bathrooms in the house.
# * Age: The age of the house in years.
# * Location: The neighborhood or area where the house is located.
# * Garage Size: The size of the garage in square feet.
# * Yard Size: The size of the yard or outdoor space in square feet.
# * Amenities: A binary feature indicating whether the house has additional amenities such as a swimming pool, gym, etc.
# * School Rating: The rating of nearby schools, on a scale from 1 to 10.
# * Distance to City Center: The distance of the house from the city center in miles.
# * Price: The selling price of the house.
#
# dataset example:
#
# data = {
#     'Area': [2000, 1800, 2500, 2200, 1900, 2800, 2100, 1700, 2400, 2000],
#     'Bedrooms': [3, 2, 4, 3, 2, 5, 4, 2, 3, 3],
#     'Bathrooms': [2, 1.5, 3, 2.5, 2, 3.5, 2.5, 1, 3, 2],
#     'Age': [10, 5, 15, 8, 3, 20, 12, 6, 18, 9],
#     'Location': ['Suburban', 'Urban', 'Rural', 'Suburban', 'Urban', 'Rural', 'Suburban', 'Urban', 'Rural', 'Suburban'],
#     'Garage_Size': [400, 300, 500, 450, 350, 600, 400, 250, 550, 400],
#     'Yard_Size': [800, 600, 1000, 900, 700, 1200, 800, 500, 1100, 800],
#     'Amenities': [1, 0, 1, 1, 0, 1, 1, 0, 1, 1],
#     'School_Rating': [8, 7, 6, 9, 8, 5, 7, 6, 4, 8],
#     'Distance_to_City_Center': [5, 2, 10, 7, 4, 15, 6, 3, 12, 5],
#     'Price': [300000, 250000, 350000, 320000, 280000, 400000, 310000, 240000, 370000, 300000]
# }

# %%
import numpy
import pandas
data={
    'Area':[2000, 1800, 2500, 2200, 1900, 2800, 2100, 1700, 2400, 2000],
    'Bedrooms':[3, 2, 4, 3, 2, 5, 4, 2, 3, 3],
    'Bathrooms':[2, 1.5, 3, 2.5, 2, 3.5, 2.5, 1, 3, 2],
    'Age':[10, 5, 15, 8, 3, 20, 12, 6, 18, 9],
    'Location':['Suburban', 'Urban', 'Rural', 'Suburban', 'Urban', 'Rural', 'Suburban', 'Urban', 'Rural', 'Suburban'],
    'Garage Size':[400, 300, 500, 450, 350, 600, 400, 250, 550, 400],
    'Yard Size':[800, 600, 1000, 900, 700, 1200, 800, 500, 1100, 800],
    'Amenities':[1, 0, 1, 1, 0, 1, 1, 0, 1, 1],
    'School Rating':[8, 7, 6, 9, 8, 5, 7, 6, 4, 8],
    'Distance to City Center':[5, 2, 10, 7, 4, 15, 6, 3, 12, 5],
    'Price':[300000, 250000, 350000, 320000, 280000, 400000, 310000, 240000, 370000, 300000]
}
df=pandas.DataFrame(data)
df
# Out:
#    Area  Bedrooms  Bathrooms  Age  Location  Garage Size  Yard Size  \
# 0  2000         3        2.0   10  Suburban          400        800
# 1  1800         2        1.5    5     Urban          300        600
# 2  2500         4        3.0   15     Rural          500       1000
# 3  2200         3        2.5    8  Suburban          450        900
# 4  1900         2        2.0    3     Urban          350        700
# 5  2800         5        3.5   20     Rural          600       1200
# 6  2100         4        2.5   12  Suburban          400        800
# 7  1700         2        1.0    6     Urban          250        500
# 8  2400         3        3.0   18     Rural          550       1100
# 9  2000         3        2.0    9  Suburban          400        800
#
#    Amenities  School Rating  Distance to City Center   Price
# 0          1              8                        5  300000
# 1          0              7                        2  250000
# 2          1              6                       10  350000
# 3          1              9                        7  320000
# 4          0              8                        4  280000
# 5          1              5                       15  400000
# 6          1              7                        6  310000
# 7          0              6                        3  240000
# 8          1              4                       12  370000
# 9          1              8                        5  300000

# %%
#predict House price and show details. while number of bedrooms > 2 and Distance to City Center < 7
df[(df['Bedrooms']>2)&(df['Distance to City Center']<7)]
# Out:
#    Area  Bedrooms  Bathrooms  Age  Location  Garage Size  Yard Size  \
# 0  2000         3        2.0   10  Suburban          400        800
# 6  2100         4        2.5   12  Suburban          400        800
# 9  2000         3        2.0    9  Suburban          400        800
#
#    Amenities  School Rating  Distance to City Center   Price
# 0          1              8                        5  300000
# 6          1              7                        6  310000
# 9          1              8                        5  300000

# %%
#predict House price while number of bedrooms > 2 and Distance to City Center < 7
df[(df['Bedrooms']>2)&(df['Distance to City Center']<7)][['Price']]
# Out:
#     Price
# 0  300000
# 6  310000
# 9  300000

# %%
#predict House price and show details where school Rating > 8
df[df['School Rating']>8]
# Out:
#    Area  Bedrooms  Bathrooms  Age  Location  Garage Size  Yard Size  \
# 3  2200         3        2.5    8  Suburban          450        900
#
#    Amenities  School Rating  Distance to City Center   Price
# 3          1              9                        7  320000

# %%
#predict House price where school Rating > 8
df[df['School Rating']>8][['Price']]
# Out:
#     Price
# 3  320000

# %% [markdown]
# # Example-9: Neural network with loss calculation

# %%
# Solve the and gate problem and then calculate the loss uisng mean square error.
# run several times of the code and compare the error. Is the result same in every case? If so, why?


import numpy as np

# use sigmoidal activation
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Define the neural network architecture
input_size = 2
hidden_size = 3
output_size = 1

# Initialize the weights and biases
W1 = np.random.randn(input_size, hidden_size)
b1 = np.random.randn(hidden_size)
W2 = np.random.randn(hidden_size, output_size)
b2 = np.random.randn(output_size)

# Define the input for the AND gate
x = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])

# Define the target output for the AND gate
target = np.array([[0], [0], [0], [1]])

# Forward pass
hidden_layer_output = (np.dot(x, W1) + b1)
output = sigmoid(np.dot(hidden_layer_output, W2) + b2)

# Calculate the loss (using Mean Squared Error)
loss = np.mean((output - target) ** 2)

print("Output:")
print(output)
print("Loss:", loss)
# Out:
# Output:
# [[0.68374902]
#  [0.65526943]
#  [0.79517822]
#  [0.77340781]]
# Loss: 0.3951357947420799

# %% [markdown]
# # Example-10: Calculate loss function and then minimize the error after Nth iterations by adjusting the parameters.

# %%
import numpy as np

# Use sigmoidal activation
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Creating loss function
def loss(predicted, actual):
    return np.mean((predicted - actual) ** 2)

# Define the neural network architecture
input_size = 2
hidden_size = 3
output_size = 1
iteration=0

# Initialize the weights and biases
W1 = np.random.randn(input_size, hidden_size)
b1 = np.random.randn(hidden_size)
W2 = np.random.randn(hidden_size, output_size)
b2 = np.random.randn(output_size)

# Define the input for the AND gate
x = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])

# Define the target output for the AND gate
target = np.array([[0], [0], [0], [1]])

# final_output
final_output=None

# Create some variables to track the best loss and the associated weights and biases
best_loss = float('inf')
best_W1 = None
best_b1 = None
best_W2 = None
best_b2 = None

for i in range(150):
    # Forward pass
    hidden_layer_output = np.dot(x, W1) + b1
    output = sigmoid(np.dot(hidden_layer_output, W2) + b2)

    # save final output
    final_output=output

    # Loss calculation
    current_loss = loss(output, target)
    iteration=iteration+1

    if current_loss < best_loss:
        print('New weights found, iteration:', iteration, 'loss:', current_loss)
        # Save current weights and biases as the best ones so far
        best_loss = current_loss
        best_W1 = W1.copy()
        best_b1 = b1.copy()
        best_W2 = W2.copy()
        best_b2 = b2.copy()
    else:
        # Revert weights and biases to the previous best values
        W1 = best_W1.copy()
        b1 = best_b1.copy()
        W2 = best_W2.copy()
        b2 = best_b2.copy()

    # Update weights with small random values
    W1 += 0.09 * np.random.randn(input_size, hidden_size)
    b1 += 0.09 * np.random.randn(hidden_size)
    W2 += 0.09 * np.random.randn(hidden_size, output_size)
    b2 += 0.09 * np.random.randn(output_size)

print(final_output)
# Out:
# New weights found, iteration: 1 loss: 0.3856947770860451
# New weights found, iteration: 3 loss: 0.36646565230696493
# New weights found, iteration: 4 loss: 0.35786897865013056
# New weights found, iteration: 5 loss: 0.31785278860266636
# New weights found, iteration: 9 loss: 0.31468496303158283
# New weights found, iteration: 10 loss: 0.3117035917458555
# New weights found, iteration: 11 loss: 0.24958071058342096
# New weights found, iteration: 16 loss: 0.22897433505687087
# New weights found, iteration: 17 loss: 0.22880515657930972
# New weights found, iteration: 18 loss: 0.21183740905778028
# New weights found, iteration: 19 loss: 0.2093258916581185
# New weights found, iteration: 20 loss: 0.20510317862723282
# New weights found, iteration: 22 loss: 0.1887070476089775
# New weights found, iteration: 27 loss: 0.18779513780327356
# New weights found, iteration: 31 loss: 0.186184498883734
# New weights found, iteration: 33 loss: 0.18186929365703083
# New weights found, iteration: 34 loss: 0.1651622484129286
# New weights found, iteration: 41 loss: 0.15402099793951693
# New weights found, iteration: 42 loss: 0.14526734480412487
# New weights found, iteration: 44 loss: 0.1387661392817085
# New weights found, iteration: 51 loss: 0.13708990176403923
# New weights found, iteration: 53 loss: 0.13614868132439795
# New weights found, iteration: 55 loss: 0.12990495753578235
# New weights found, iteration: 59 loss: 0.12913655441972216
# New weights found, iteration: 61 loss: 0.1198561805699116
# New weights found, iteration: 65 loss: 0.11861553761539843
# New weights found, iteration: 66 loss: 0.10407876279010844
# New weights found, iteration: 77 loss: 0.09668801080878399
# New weights found, iteration: 79 loss: 0.0809506796606894
# New weights found, iteration: 82 loss: 0.07823798495769194
# New weights found, iteration: 86 loss: 0.07331423030454373
# New weights found, iteration: 92 loss: 0.07100930159067172
# New weights found, iteration: 94 loss: 0.06504373322997697
# New weights found, iteration: 102 loss: 0.05482163418790678
# New weights found, iteration: 104 loss: 0.05459889037516674
# New weights found, iteration: 108 loss: 0.04912161056222834
# New weights found, iteration: 119 loss: 0.046977049828102774
# New weights found, iteration: 125 loss: 0.04332594627242096
# New weights found, iteration: 129 loss: 0.040100050866016146
# New weights found, iteration: 130 loss: 0.03707186501075195
# New weights found, iteration: 132 loss: 0.03569042297158895
# New weights found, iteration: 138 loss: 0.03242659703732026
# New weights found, iteration: 145 loss: 0.03093062694080017
# New weights found, iteration: 150 loss: 0.028320584467295306
# [[0.0107569 ]
#  [0.14032432]
#  [0.15829602]
#  [0.73843149]]

# %% [markdown]
# # Can we randomly get weights and biases every time to minimize the error?
# # Do we have any alternate option to do this efficiently?

# %% [markdown]
# # Exercise: Modify the Example-10 in such a way that the neural network updates its parameters until the error or loss reaches to 5%.

# %%
import numpy as np

# Use sigmoidal activation
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Creating loss function
def loss(predicted, actual):
    return np.mean((predicted - actual) ** 2)

# Define the neural network architecture
input_size = 2
hidden_size = 3
output_size = 1
iteration=0

# Initialize the weights and biases
W1 = np.random.randn(input_size, hidden_size)
b1 = np.random.randn(hidden_size)
W2 = np.random.randn(hidden_size, output_size)
b2 = np.random.randn(output_size)

# Define the input for the AND gate
x = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])

# Define the target output for the AND gate
target = np.array([[0], [0], [0], [1]])

# final_output
final_output=None

# Create some variables to track the best loss and the associated weights and biases
best_loss = float('inf')
best_W1 = None
best_b1 = None
best_W2 = None
best_b2 = None

while(best_loss>=0.05):
    # Forward pass
    hidden_layer_output = np.dot(x, W1) + b1
    output = sigmoid(np.dot(hidden_layer_output, W2) + b2)

    # save final output
    final_output=output

    # Loss calculation
    current_loss = loss(output, target)
    iteration=iteration+1

    if current_loss < best_loss:
        print('New weights found, iteration:', iteration, 'loss:', current_loss)
        # Save current weights and biases as the best ones so far
        best_loss = current_loss
        best_W1 = W1.copy()
        best_b1 = b1.copy()
        best_W2 = W2.copy()
        best_b2 = b2.copy()
    else:
        # Revert weights and biases to the previous best values
        W1 = best_W1.copy()
        b1 = best_b1.copy()
        W2 = best_W2.copy()
        b2 = best_b2.copy()

    # Update weights with small random values
    W1 += 0.09 * np.random.randn(input_size, hidden_size)
    b1 += 0.09 * np.random.randn(hidden_size)
    W2 += 0.09 * np.random.randn(hidden_size, output_size)
    b2 += 0.09 * np.random.randn(output_size)

print(final_output)
# Out:
# New weights found, iteration: 1 loss: 0.6696150906736721
# New weights found, iteration: 2 loss: 0.6410373352723467
# New weights found, iteration: 3 loss: 0.6110685182805038
# New weights found, iteration: 4 loss: 0.5893493649097339
# New weights found, iteration: 5 loss: 0.5472490572757025
# New weights found, iteration: 6 loss: 0.5027465886244963
# New weights found, iteration: 8 loss: 0.49099642819352923
# New weights found, iteration: 10 loss: 0.4777307688260647
# New weights found, iteration: 11 loss: 0.42172150730148505
# New weights found, iteration: 12 loss: 0.34713507885619355
# New weights found, iteration: 13 loss: 0.3335438965168516
# New weights found, iteration: 14 loss: 0.30024279848047347
# New weights found, iteration: 17 loss: 0.29400191275957166
# New weights found, iteration: 20 loss: 0.28443526506614336
# New weights found, iteration: 22 loss: 0.28147572399389664
# New weights found, iteration: 25 loss: 0.2814136845013111
# New weights found, iteration: 34 loss: 0.2740290092801393
# New weights found, iteration: 35 loss: 0.2525640147125598
# New weights found, iteration: 37 loss: 0.24110313896012567
# New weights found, iteration: 40 loss: 0.2285374531875461
# New weights found, iteration: 41 loss: 0.21384784705435597
# New weights found, iteration: 42 loss: 0.20555303623900936
# New weights found, iteration: 45 loss: 0.19636422876814302
# New weights found, iteration: 50 loss: 0.1845018875556269
# New weights found, iteration: 51 loss: 0.1747664052003975
# New weights found, iteration: 52 loss: 0.16375687923310722
# New weights found, iteration: 54 loss: 0.15018679239233323
# New weights found, iteration: 55 loss: 0.1467132587588245
# New weights found, iteration: 56 loss: 0.11900405870747183
# New weights found, iteration: 58 loss: 0.07864026214879435
# New weights found, iteration: 60 loss: 0.0749398598002207
# New weights found, iteration: 61 loss: 0.0736618822209978
# New weights found, iteration: 65 loss: 0.07050452241622555
# New weights found, iteration: 66 loss: 0.06179310348007201
# New weights found, iteration: 67 loss: 0.05682971906744066
# New weights found, iteration: 69 loss: 0.05471417591571703
# New weights found, iteration: 70 loss: 0.05240505191024525
# New weights found, iteration: 74 loss: 0.04645732373834531
# [[0.029008  ]
#  [0.20843269]
#  [0.32381779]
#  [0.80846493]]

# %% [markdown]
# # Example-11: Solving AND gate problem using neural network with backpropagation approach.

# %%
import numpy as np

# Define the sigmoid activation function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Define the derivative of the sigmoid activation function
def sigmoid_derivative(x):
    return sigmoid(x) * (1 - sigmoid(x))

# Define the input data and labels for the AND gate problem
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [0], [0], [1]])

# Initialize the weights and biases with random values
np.random.seed(42)
W = np.random.randn(2, 1)
b = np.random.randn(1)

# Set the learning rate and number of epochs
learning_rate = 0.8
num_epochs = 500

# Training loop
for epoch in range(num_epochs):
    # Forward pass
    z = np.dot(X, W) + b
    a = sigmoid(z)

    # Compute the loss
    loss = np.mean((y - a) ** 2)

    error= (y - a)
    # Backpropagation
    delta = error * sigmoid_derivative(z)
    dW = np.dot(X.T, delta)
    db = np.sum(delta)

    # Update the weights and biases
    W -= learning_rate * dW
    b -= learning_rate * db

    # Print the loss at every 100 epochs
    if (epoch + 1) % 100 == 0:
        print(f"Epoch {epoch + 1}: Loss = {loss}")

# Test the model on the input data
#predictions = (a >= 0.5).astype(int)
print("Predicted Output:")
print(a)
# Out:
# Epoch 100: Loss = 0.743998459915124
# Epoch 200: Loss = 0.7470214794177472
# Epoch 300: Loss = 0.7480165507492393
# Epoch 400: Loss = 0.748512245347843
# Epoch 500: Loss = 0.7488092427954165
# Predicted Output:
# [[0.99836331]
#  [0.99958641]
#  [0.99966728]
#  [0.999916  ]]

# %% [markdown]
# # HW: Solve OR, NOR, NAND using backpropagation algorithm

# %%
#For OR gate
import numpy as np


class NeuralNetwork:
	def __init__(self, input_size, output_size):
		self.input_size = input_size
		self.output_size = output_size

		# Initialize weights
		self.weights_input = np.random.randn(self.input_size, self.output_size)
		# Initialize the biases
		self.bias_output = np.zeros((1, self.output_size))

	def sigmoid(self, x):
		return 1 / (1 + np.exp(-x))

	def sigmoid_derivative(self, x):
		return x * (1 - x)

	def feedforward(self, X):

		self.output_activation = np.dot(X, self.weights_input) + self.bias_output
		self.predicted_output = self.sigmoid(self.output_activation)

		return self.predicted_output

	def backward(self, X, y, learning_rate):
		# Compute the output layer error
		output_error = y - self.predicted_output
		output_delta = output_error * self.sigmoid_derivative(self.predicted_output)

		# Update weights and biases
		self.weights_input += np.dot(X.T, output_delta) * learning_rate
		self.bias_output += np.sum(output_delta, axis=0, keepdims=True) * learning_rate

	def train(self, X, y, epochs, learning_rate):
		for epoch in range(epochs):
			output = self.feedforward(X)
			self.backward(X, y, learning_rate)
			if epoch % 4000 == 0:
				loss = np.mean(np.square(y - output))
				print(f"Epoch {epoch}, Loss:{loss}")

X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [1]])

nn = NeuralNetwork(input_size=2, output_size=1)
nn.train(X, y, epochs=10000, learning_rate=0.1)

# Test the trained model
output = nn.feedforward(X)
print("Predictions after training:")
print(output)
# Out:
# Epoch 0, Loss:0.1600973137463086
# Epoch 4000, Loss:0.0036591726483842036
# Epoch 8000, Loss:0.0017052955101924292
# Predictions after training:
# [[0.05483208]
#  [0.9657468 ]
#  [0.96575877]
#  [0.99992705]]

# %%
#For NAND gate
import numpy as np


class NeuralNetwork:
	def __init__(self, input_size, output_size):
		self.input_size = input_size
		self.output_size = output_size

		# Initialize weights
		self.weights_input = np.random.randn(self.input_size, self.output_size)
		# Initialize the biases
		self.bias_output = np.zeros((1, self.output_size))

	def sigmoid(self, x):
		return 1 / (1 + np.exp(-x))

	def sigmoid_derivative(self, x):
		return x * (1 - x)

	def feedforward(self, X):

		self.output_activation = np.dot(X, self.weights_input) + self.bias_output
		self.predicted_output = self.sigmoid(self.output_activation)

		return self.predicted_output

	def backward(self, X, y, learning_rate):
		# Compute the output layer error
		output_error = y - self.predicted_output
		output_delta = output_error * self.sigmoid_derivative(self.predicted_output)

		# Update weights and biases
		self.weights_input += np.dot(X.T, output_delta) * learning_rate
		self.bias_output += np.sum(output_delta, axis=0, keepdims=True) * learning_rate

	def train(self, X, y, epochs, learning_rate):
		for epoch in range(epochs):
			output = self.feedforward(X)
			self.backward(X, y, learning_rate)
			if epoch % 4000 == 0:
				loss = np.mean(np.square(y - output))
				print(f"Epoch {epoch}, Loss:{loss}")

X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[1], [1], [1], [0]])

nn = NeuralNetwork(input_size=2, output_size=1)
nn.train(X, y, epochs=10000, learning_rate=0.1)

# Test the trained model
output = nn.feedforward(X)
print("Predictions after training:")
print(output)
# Out:
# Epoch 0, Loss:0.30505868618713006
# Epoch 4000, Loss:0.0074841677114572125
# Epoch 8000, Loss:0.0034198854067487294
# Predictions after training:
# [[0.9997504 ]
#  [0.94411568]
#  [0.94411568]
#  [0.06651591]]

# %%
#For NOR gate
import numpy as np


class NeuralNetwork:
	def __init__(self, input_size, output_size):
		self.input_size = input_size
		self.output_size = output_size

		# Initialize weights
		self.weights_input = np.random.randn(self.input_size, self.output_size)
		# Initialize the biases
		self.bias_output = np.zeros((1, self.output_size))

	def sigmoid(self, x):
		return 1 / (1 + np.exp(-x))

	def sigmoid_derivative(self, x):
		return x * (1 - x)

	def feedforward(self, X):

		self.output_activation = np.dot(X, self.weights_input) + self.bias_output
		self.predicted_output = self.sigmoid(self.output_activation)

		return self.predicted_output

	def backward(self, X, y, learning_rate):
		# Compute the output layer error
		output_error = y - self.predicted_output
		output_delta = output_error * self.sigmoid_derivative(self.predicted_output)

		# Update weights and biases
		self.weights_input += np.dot(X.T, output_delta) * learning_rate
		self.bias_output += np.sum(output_delta, axis=0, keepdims=True) * learning_rate

	def train(self, X, y, epochs, learning_rate):
		for epoch in range(epochs):
			output = self.feedforward(X)
			self.backward(X, y, learning_rate)
			if epoch % 4000 == 0:
				loss = np.mean(np.square(y - output))
				print(f"Epoch {epoch}, Loss:{loss}")

X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[1], [0], [0], [0]])

nn = NeuralNetwork(input_size=2, output_size=1)
nn.train(X, y, epochs=10000, learning_rate=0.1)

# Test the trained model
output = nn.feedforward(X)
print("Predictions after training:")
print(output)
# Out:
# Epoch 0, Loss:0.29846976464594593
# Epoch 4000, Loss:0.0037532081612917357
# Epoch 8000, Loss:0.001726539879565588
# Predictions after training:
# [[9.44896283e-01]
#  [3.44121256e-02]
#  [3.44170330e-02]
#  [7.40743953e-05]]

# %% [markdown]
# # Exercise: Solve the XOR gate using backpropagation

# %%
import numpy as np


class NeuralNetwork:
	def __init__(self, input_size, hidden_size, output_size):
		self.input_size = input_size
		self.hidden_size = hidden_size
		self.output_size = output_size

		# Initialize weights
		self.weights_input_hidden = np.random.randn(self.input_size, self.hidden_size)
		self.weights_hidden_output = np.random.randn(self.hidden_size, self.output_size)

		# Initialize the biases
		self.bias_hidden = np.zeros((1, self.hidden_size))
		self.bias_output = np.zeros((1, self.output_size))

	def sigmoid(self, x):
		return 1 / (1 + np.exp(-x))

	def sigmoid_derivative(self, x):
		return x * (1 - x)

	def feedforward(self, X):
		# Input to hidden
		self.hidden_activation = np.dot(X, self.weights_input_hidden) + self.bias_hidden
		self.hidden_output = self.sigmoid(self.hidden_activation)

		# Hidden to output
		self.output_activation = np.dot(self.hidden_output, self.weights_hidden_output) + self.bias_output
		self.predicted_output = self.sigmoid(self.output_activation)

		return self.predicted_output

	def backward(self, X, y, learning_rate):
		# Compute the output layer error
		output_error = y - self.predicted_output
		output_delta = output_error * self.sigmoid_derivative(self.predicted_output)

		# Compute the hidden layer error
		hidden_error = np.dot(output_delta, self.weights_hidden_output.T)
		hidden_delta = hidden_error * self.sigmoid_derivative(self.hidden_output)

		# Update weights and biases
		self.weights_hidden_output += np.dot(self.hidden_output.T, output_delta) * learning_rate
		self.bias_output += np.sum(output_delta, axis=0, keepdims=True) * learning_rate
		self.weights_input_hidden += np.dot(X.T, hidden_delta) * learning_rate
		self.bias_hidden += np.sum(hidden_delta, axis=0, keepdims=True) * learning_rate

	def train(self, X, y, epochs, learning_rate):
		for epoch in range(epochs):
			output = self.feedforward(X)
			self.backward(X, y, learning_rate)
			if epoch % 4000 == 0:
				loss = np.mean(np.square(y - output))
				print(f"Epoch {epoch}, Loss:{loss}")

X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])

nn = NeuralNetwork(input_size=2, hidden_size=4, output_size=1)
nn.train(X, y, epochs=10000, learning_rate=0.1)

# Test the trained model
output = nn.feedforward(X)
print("Predictions after training:")
print(output)
# Out:
# Epoch 0, Loss:0.24523069991578134
# Epoch 4000, Loss:0.028295758154487642
# Epoch 8000, Loss:0.004095837726823765
# Predictions after training:
# [[0.03699176]
#  [0.9402164 ]
#  [0.9654643 ]
#  [0.06673297]]

# %% [markdown]
# # Example-11: A complete guide of neural network with backpropragation for the following network:
#
# ![image.png](data:image/png;base64,...)
#
# Dataset:
# ![image.png](data:image/png;base64,...)

# %%
# source doce: https://towardsdatascience.com/machine-learning-for-beginners-an-introduction-to-neural-networks-d49f22d238f9

import numpy as np

def sigmoid(x):
  # Sigmoid activation function: f(x) = 1 / (1 + e^(-x))
  return 1 / (1 + np.exp(-x))

def deriv_sigmoid(x):
  # Derivative of sigmoid: f'(x) = f(x) * (1 - f(x))
  fx = sigmoid(x)
  return fx * (1 - fx)

def mse_loss(y_true, y_pred):
  # y_true and y_pred are numpy arrays of the same length.
  return ((y_true - y_pred) ** 2).mean()

class OurNeuralNetwork:
  '''
  A neural network with:
    - 2 inputs
    - a hidden layer with 2 neurons (h1, h2)
    - an output layer with 1 neuron (o1)

  *** DISCLAIMER ***:
  The code below is intended to be simple and educational, NOT optimal.
  Real neural net code looks nothing like this. DO NOT use this code.
  Instead, read/run it to understand how this specific network works.
  '''
  def __init__(self):
    # Weights
    self.w1 = np.random.normal()
    self.w2 = np.random.normal()
    self.w3 = np.random.normal()
    self.w4 = np.random.normal()
    self.w5 = np.random.normal()
    self.w6 = np.random.normal()

    # Biases
    self.b1 = np.random.normal()
    self.b2 = np.random.normal()
    self.b3 = np.random.normal()

  def feedforward(self, x):
    # x is a numpy array with 2 elements.
    h1 = sigmoid(self.w1 * x[0] + self.w2 * x[1] + self.b1)
    h2 = sigmoid(self.w3 * x[0] + self.w4 * x[1] + self.b2)
    o1 = sigmoid(self.w5 * h1 + self.w6 * h2 + self.b3)
    return o1

  def train(self, data, all_y_trues):
    '''
    - data is a (n x 2) numpy array, n = # of samples in the dataset.
    - all_y_trues is a numpy array with n elements.
      Elements in all_y_trues correspond to those in data.
    '''
    learn_rate = 0.1
    epochs = 1000 # number of times to loop through the entire dataset

    for epoch in range(epochs):
      for x, y_true in zip(data, all_y_trues):
        # --- Do a feedforward (we'll need these values later)
        sum_h1 = self.w1 * x[0] + self.w2 * x[1] + self.b1
        h1 = sigmoid(sum_h1)

        sum_h2 = self.w3 * x[0] + self.w4 * x[1] + self.b2
        h2 = sigmoid(sum_h2)

        sum_o1 = self.w5 * h1 + self.w6 * h2 + self.b3
        o1 = sigmoid(sum_o1)
        y_pred = o1

        # --- Calculate partial derivatives.
        # --- Naming: d_L_d_w1 represents "partial L / partial w1"
        d_L_d_ypred = -2 * (y_true - y_pred)

        # Neuron o1
        d_ypred_d_w5 = h1 * deriv_sigmoid(sum_o1)
        d_ypred_d_w6 = h2 * deriv_sigmoid(sum_o1)
        d_ypred_d_b3 = deriv_sigmoid(sum_o1)

        d_ypred_d_h1 = self.w5 * deriv_sigmoid(sum_o1)
        d_ypred_d_h2 = self.w6 * deriv_sigmoid(sum_o1)

        # Neuron h1
        d_h1_d_w1 = x[0] * deriv_sigmoid(sum_h1)
        d_h1_d_w2 = x[1] * deriv_sigmoid(sum_h1)
        d_h1_d_b1 = deriv_sigmoid(sum_h1)

        # Neuron h2
        d_h2_d_w3 = x[0] * deriv_sigmoid(sum_h2)
        d_h2_d_w4 = x[1] * deriv_sigmoid(sum_h2)
        d_h2_d_b2 = deriv_sigmoid(sum_h2)

        # --- Update weights and biases
        # Neuron h1
        self.w1 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w1
        self.w2 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w2
        self.b1 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_b1

        # Neuron h2
        self.w3 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_w3
        self.w4 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_w4
        self.b2 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_b2

        # Neuron o1
        self.w5 -= learn_rate * d_L_d_ypred * d_ypred_d_w5
        self.w6 -= learn_rate * d_L_d_ypred * d_ypred_d_w6
        self.b3 -= learn_rate * d_L_d_ypred * d_ypred_d_b3

      # --- Calculate total loss at the end of each epoch
      if epoch % 10 == 0:
        y_preds = np.apply_along_axis(self.feedforward, 1, data)
        loss = mse_loss(all_y_trues, y_preds)
        print("Epoch %d loss: %.3f" % (epoch, loss))


# Define dataset
data = np.array([
  [-2, -1],  # Alice
  [25, 6],   # Bob
  [17, 4],   # Charlie
  [-15, -6], # Diana
])
all_y_trues = np.array([
  1, # Alice
  0, # Bob
  0, # Charlie
  1, # Diana
])

# Train our neural network!
network = OurNeuralNetwork()
network.train(data, all_y_trues)
# Out:
# Epoch 0 loss: 0.391
# Epoch 10 loss: 0.249
# Epoch 20 loss: 0.168
# Epoch 30 loss: 0.127
# Epoch 40 loss: 0.100
# Epoch 50 loss: 0.081
# Epoch 60 loss: 0.067
# Epoch 70 loss: 0.057
# Epoch 80 loss: 0.048
# Epoch 90 loss: 0.042
# Epoch 100 loss: 0.037
# Epoch 110 loss: 0.033
# Epoch 120 loss: 0.030
# Epoch 130 loss: 0.027
# Epoch 140 loss: 0.024
# Epoch 150 loss: 0.022
# Epoch 160 loss: 0.021
# Epoch 170 loss: 0.019
# Epoch 180 loss: 0.018
# Epoch 190 loss: 0.017
# Epoch 200 loss: 0.016
# Epoch 210 loss: 0.015
# Epoch 220 loss: 0.014
# Epoch 230 loss: 0.013
# Epoch 240 loss: 0.013
# Epoch 250 loss: 0.012
# Epoch 260 loss: 0.011
# Epoch 270 loss: 0.011
# Epoch 280 loss: 0.010
# Epoch 290 loss: 0.010
# Epoch 300 loss: 0.010
# Epoch 310 loss: 0.009
# Epoch 320 loss: 0.009
# Epoch 330 loss: 0.009
# Epoch 340 loss: 0.008
# Epoch 350 loss: 0.008
# Epoch 360 loss: 0.008
# Epoch 370 loss: 0.007
# Epoch 380 loss: 0.007
# Epoch 390 loss: 0.007
# Epoch 400 loss: 0.007
# Epoch 410 loss: 0.007
# Epoch 420 loss: 0.006
# Epoch 430 loss: 0.006
# Epoch 440 loss: 0.006
# Epoch 450 loss: 0.006
# Epoch 460 loss: 0.006
# Epoch 470 loss: 0.006
# Epoch 480 loss: 0.005
# Epoch 490 loss: 0.005
# Epoch 500 loss: 0.005
# Epoch 510 loss: 0.005
# Epoch 520 loss: 0.005
# Epoch 530 loss: 0.005
# Epoch 540 loss: 0.005
# Epoch 550 loss: 0.005
# Epoch 560 loss: 0.005
# Epoch 570 loss: 0.004
# Epoch 580 loss: 0.004
# Epoch 590 loss: 0.004
# Epoch 600 loss: 0.004
# Epoch 610 loss: 0.004
# Epoch 620 loss: 0.004
# Epoch 630 loss: 0.004
# Epoch 640 loss: 0.004
# Epoch 650 loss: 0.004
# Epoch 660 loss: 0.004
# Epoch 670 loss: 0.004
# Epoch 680 loss: 0.004
# Epoch 690 loss: 0.004
# Epoch 700 loss: 0.004
# Epoch 710 loss: 0.003
# Epoch 720 loss: 0.003
# Epoch 730 loss: 0.003
# Epoch 740 loss: 0.003
# Epoch 750 loss: 0.003
# Epoch 760 loss: 0.003
# Epoch 770 loss: 0.003
# Epoch 780 loss: 0.003
# Epoch 790 loss: 0.003
# Epoch 800 loss: 0.003
# Epoch 810 loss: 0.003
# Epoch 820 loss: 0.003
# Epoch 830 loss: 0.003
# Epoch 840 loss: 0.003
# Epoch 850 loss: 0.003
# Epoch 860 loss: 0.003
# Epoch 870 loss: 0.003
# Epoch 880 loss: 0.003
# Epoch 890 loss: 0.003
# Epoch 900 loss: 0.003
# Epoch 910 loss: 0.003
# Epoch 920 loss: 0.003
# Epoch 930 loss: 0.003
# Epoch 940 loss: 0.003
# Epoch 950 loss: 0.002
# Epoch 960 loss: 0.002
# Epoch 970 loss: 0.002
# Epoch 980 loss: 0.002
# Epoch 990 loss: 0.002

# %%
# Make some predictions
emily = np.array([-7, -3]) # 128 pounds, 63 inches
frank = np.array([20, 2])  # 155 pounds, 68 inches
print("Emily: %.3f" % network.feedforward(emily)) # 0.951 - F
print("Frank: %.3f" % network.feedforward(frank)) # 0.039 - M
# Out:
# Emily: 0.965
# Frank: 0.056

# %% [markdown]
# #Exercise: draw the following figure based on the outputs of example-11:
# ![image.png](data:image/png;base64,...)

# %%
# source doce: https://towardsdatascience.com/machine-learning-for-beginners-an-introduction-to-neural-networks-d49f22d238f9

import numpy as np
rafi=[]
shafi=[]
def sigmoid(x):
  # Sigmoid activation function: f(x) = 1 / (1 + e^(-x))
  return 1 / (1 + np.exp(-x))

def deriv_sigmoid(x):
  # Derivative of sigmoid: f'(x) = f(x) * (1 - f(x))
  fx = sigmoid(x)
  return fx * (1 - fx)

def mse_loss(y_true, y_pred):
  # y_true and y_pred are numpy arrays of the same length.
  return ((y_true - y_pred) ** 2).mean()

class OurNeuralNetwork:
  '''
  A neural network with:
    - 2 inputs
    - a hidden layer with 2 neurons (h1, h2)
    - an output layer with 1 neuron (o1)

  *** DISCLAIMER ***:
  The code below is intended to be simple and educational, NOT optimal.
  Real neural net code looks nothing like this. DO NOT use this code.
  Instead, read/run it to understand how this specific network works.
  '''
  def __init__(self):
    # Weights
    self.w1 = np.random.normal()
    self.w2 = np.random.normal()
    self.w3 = np.random.normal()
    self.w4 = np.random.normal()
    self.w5 = np.random.normal()
    self.w6 = np.random.normal()

    # Biases
    self.b1 = np.random.normal()
    self.b2 = np.random.normal()
    self.b3 = np.random.normal()

  def feedforward(self, x):
    # x is a numpy array with 2 elements.
    h1 = sigmoid(self.w1 * x[0] + self.w2 * x[1] + self.b1)
    h2 = sigmoid(self.w3 * x[0] + self.w4 * x[1] + self.b2)
    o1 = sigmoid(self.w5 * h1 + self.w6 * h2 + self.b3)
    return o1

  def train(self, data, all_y_trues):
    '''
    - data is a (n x 2) numpy array, n = # of samples in the dataset.
    - all_y_trues is a numpy array with n elements.
      Elements in all_y_trues correspond to those in data.
    '''
    learn_rate = 0.1
    epochs = 1000 # number of times to loop through the entire dataset

    for epoch in range(epochs):
      for x, y_true in zip(data, all_y_trues):
        # --- Do a feedforward (we'll need these values later)
        sum_h1 = self.w1 * x[0] + self.w2 * x[1] + self.b1
        h1 = sigmoid(sum_h1)

        sum_h2 = self.w3 * x[0] + self.w4 * x[1] + self.b2
        h2 = sigmoid(sum_h2)

        sum_o1 = self.w5 * h1 + self.w6 * h2 + self.b3
        o1 = sigmoid(sum_o1)
        y_pred = o1

        # --- Calculate partial derivatives.
        # --- Naming: d_L_d_w1 represents "partial L / partial w1"
        d_L_d_ypred = -2 * (y_true - y_pred)

        # Neuron o1
        d_ypred_d_w5 = h1 * deriv_sigmoid(sum_o1)
        d_ypred_d_w6 = h2 * deriv_sigmoid(sum_o1)
        d_ypred_d_b3 = deriv_sigmoid(sum_o1)

        d_ypred_d_h1 = self.w5 * deriv_sigmoid(sum_o1)
        d_ypred_d_h2 = self.w6 * deriv_sigmoid(sum_o1)

        # Neuron h1
        d_h1_d_w1 = x[0] * deriv_sigmoid(sum_h1)
        d_h1_d_w2 = x[1] * deriv_sigmoid(sum_h1)
        d_h1_d_b1 = deriv_sigmoid(sum_h1)

        # Neuron h2
        d_h2_d_w3 = x[0] * deriv_sigmoid(sum_h2)
        d_h2_d_w4 = x[1] * deriv_sigmoid(sum_h2)
        d_h2_d_b2 = deriv_sigmoid(sum_h2)

        # --- Update weights and biases
        # Neuron h1
        self.w1 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w1
        self.w2 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w2
        self.b1 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_b1

        # Neuron h2
        self.w3 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_w3
        self.w4 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_w4
        self.b2 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_b2

        # Neuron o1
        self.w5 -= learn_rate * d_L_d_ypred * d_ypred_d_w5
        self.w6 -= learn_rate * d_L_d_ypred * d_ypred_d_w6
        self.b3 -= learn_rate * d_L_d_ypred * d_ypred_d_b3

      # --- Calculate total loss at the end of each epoch
      if epoch % 10 == 0:
        y_preds = np.apply_along_axis(self.feedforward, 1, data)
        loss = mse_loss(all_y_trues, y_preds)
        print("Epoch %d loss: %.3f" % (epoch, loss))
        rafi.append(epoch)
        shafi.append(loss)

# Define dataset
data = np.array([
  [-2, -1],  # Alice
  [25, 6],   # Bob
  [17, 4],   # Charlie
  [-15, -6], # Diana
])
all_y_trues = np.array([
  1, # Alice
  0, # Bob
  0, # Charlie
  1, # Diana
])

# Train our neural network!
network = OurNeuralNetwork()
network.train(data, all_y_trues)
# Out:
# Epoch 0 loss: 0.383
# Epoch 10 loss: 0.133
# Epoch 20 loss: 0.071
# Epoch 30 loss: 0.049
# Epoch 40 loss: 0.038
# Epoch 50 loss: 0.031
# Epoch 60 loss: 0.027
# Epoch 70 loss: 0.023
# Epoch 80 loss: 0.020
# Epoch 90 loss: 0.018
# Epoch 100 loss: 0.017
# Epoch 110 loss: 0.015
# Epoch 120 loss: 0.014
# Epoch 130 loss: 0.013
# Epoch 140 loss: 0.012
# Epoch 150 loss: 0.011
# Epoch 160 loss: 0.010
# Epoch 170 loss: 0.010
# Epoch 180 loss: 0.009
# Epoch 190 loss: 0.009
# Epoch 200 loss: 0.008
# Epoch 210 loss: 0.008
# Epoch 220 loss: 0.007
# Epoch 230 loss: 0.007
# Epoch 240 loss: 0.007
# Epoch 250 loss: 0.006
# Epoch 260 loss: 0.006
# Epoch 270 loss: 0.006
# Epoch 280 loss: 0.006
# Epoch 290 loss: 0.005
# Epoch 300 loss: 0.005
# Epoch 310 loss: 0.005
# Epoch 320 loss: 0.005
# Epoch 330 loss: 0.005
# Epoch 340 loss: 0.005
# Epoch 350 loss: 0.004
# Epoch 360 loss: 0.004
# Epoch 370 loss: 0.004
# Epoch 380 loss: 0.004
# Epoch 390 loss: 0.004
# Epoch 400 loss: 0.004
# Epoch 410 loss: 0.004
# Epoch 420 loss: 0.004
# Epoch 430 loss: 0.004
# Epoch 440 loss: 0.003
# Epoch 450 loss: 0.003
# Epoch 460 loss: 0.003
# Epoch 470 loss: 0.003
# Epoch 480 loss: 0.003
# Epoch 490 loss: 0.003
# Epoch 500 loss: 0.003
# Epoch 510 loss: 0.003
# Epoch 520 loss: 0.003
# Epoch 530 loss: 0.003
# Epoch 540 loss: 0.003
# Epoch 550 loss: 0.003
# Epoch 560 loss: 0.003
# Epoch 570 loss: 0.003
# Epoch 580 loss: 0.003
# Epoch 590 loss: 0.003
# Epoch 600 loss: 0.003
# Epoch 610 loss: 0.002
# Epoch 620 loss: 0.002
# Epoch 630 loss: 0.002
# Epoch 640 loss: 0.002
# Epoch 650 loss: 0.002
# Epoch 660 loss: 0.002
# Epoch 670 loss: 0.002
# Epoch 680 loss: 0.002
# Epoch 690 loss: 0.002
# Epoch 700 loss: 0.002
# Epoch 710 loss: 0.002
# Epoch 720 loss: 0.002
# Epoch 730 loss: 0.002
# Epoch 740 loss: 0.002
# Epoch 750 loss: 0.002
# Epoch 760 loss: 0.002
# Epoch 770 loss: 0.002
# Epoch 780 loss: 0.002
# Epoch 790 loss: 0.002
# Epoch 800 loss: 0.002
# Epoch 810 loss: 0.002
# Epoch 820 loss: 0.002
# Epoch 830 loss: 0.002
# Epoch 840 loss: 0.002
# Epoch 850 loss: 0.002
# Epoch 860 loss: 0.002
# Epoch 870 loss: 0.002
# Epoch 880 loss: 0.002
# Epoch 890 loss: 0.002
# Epoch 900 loss: 0.002
# Epoch 910 loss: 0.002
# Epoch 920 loss: 0.002
# Epoch 930 loss: 0.002
# Epoch 940 loss: 0.002
# Epoch 950 loss: 0.002
# Epoch 960 loss: 0.002
# Epoch 970 loss: 0.001
# Epoch 980 loss: 0.001
# Epoch 990 loss: 0.001

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
plt.plot(rafi,shafi)
